# %% [markdown]
# # Data Exploration in R

# %% [markdown]
# 1. [Data wrangling](#wrangling)
#     - [Data import](#import)

# %% [markdown]
# Before starting, it is necessary to load the required packages. Both `ggplot2`, `dplyr` and `readr` are included in the [`tidyverse`](https://www.tidyverse.org/) package collection, so you can load just this package.
#
# Note: in the case you use a jupiter notebook you have to load the packages one by one.

# %%
# library(tidyverse)
library(dplyr)
library(ggplot2)
library(readr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# # 1. Data wrangling {#wrangling}
#
# This is the art of getting your data into R in a useful form for visualisation and modelling. Data wrangling is very important: without it you can’t work with your own data!
#
# This phase is divided into data import and the idea of tidy data (how you can organise your data in R).
#
#
#
#
#
# ### Data import {#import}
#
# In this part, we are going to learn how to get your data from disk and into R. There ara several functions to load data in R. You must choose the ideal depending on the data format.  If you’re looking for raw speed with a big dataset try `data.table::fread()`. For hierarchical data as json files, you can use `jsonlite` packages.

# %%
# Download if needed
# download.file("http://data.insideairbnb.com/spain/catalonia/barcelona/2018-09-11/visualisations/listings.csv", 
#             "airbnb.csv")

# %%
data <- read.csv("airbnb.csv") # warning message is due to a problem

# %%
data <- as_tibble(data) # tibble is structure designed for using with big dataset

# %% [markdown]
# ### Data structure
#
# Now we will have a look at data, their size and their structure.

# %%
dim(data)
# Out:
# [1] 19200    16

# %%
names(data)
# Out:
#  [1] "id"                             "name"
#  [3] "host_id"                        "host_name"
#  [5] "neighbourhood_group"            "neighbourhood"
#  [7] "latitude"                       "longitude"
#  [9] "room_type"                      "price"
# [11] "minimum_nights"                 "number_of_reviews"
# [13] "last_review"                    "reviews_per_month"
# [15] "calculated_host_listings_count" "availability_365"

# %%
str(data)
# Out:
# Classes ‘tbl_df’, ‘tbl’ and 'data.frame':	19200 obs. of  16 variables:
#  $ id                            : int  11368 18666 18674 21605 25786 31377 31380 31823 31958 32471 ...
#  $ name                          : Factor w/ 18550 levels "","  MODERNIST ROOM & PRIVATE LIVING",..: 4184 8256 10509 12631 12281 14813 14815 2182 8442 8443 ...
#  $ host_id                       : int  42188 71615 71615 82522 108310 134698 134698 136853 136853 136853 ...
#  $ host_name                     : Factor w/ 4178 levels "","* Noemi","08028 Apartments",..: 3155 2811 2811 2739 3198 3737 3737 1260 1260 1260 ...
#  $ neighbourhood_group           : Factor w/ 10 levels "Ciutat Vella",..: 1 8 2 8 3 4 4 2 3 3 ...
#  $ neighbourhood                 : Factor w/ 72 levels "Baró de Viver",..: 20 35 60 44 69 30 30 48 34 34 ...
#  $ latitude                      : num  41.4 41.4 41.4 41.4 41.4 ...
#  $ longitude                     : num  2.18 2.19 2.17 2.2 2.16 ...
#  $ room_type                     : Factor w/ 3 levels "Entire home/apt",..: 1 1 1 2 2 2 2 1 1 1 ...
#  $ price                         : int  100 130 95 33 42 42 53 75 65 95 ...
#  $ minimum_nights                : int  3 3 1 2 1 3 3 1 1 1 ...
#  $ number_of_reviews             : int  41 1 5 90 204 4 38 58 146 67 ...
#  $ last_review                   : Factor w/ 935 levels "","2011-01-04",..: 911 137 850 913 929 752 775 919 913 897 ...
#  $ reviews_per_month             : num  0.45 0.03 0.08 3.15 2.07 0.1 0.97 0.59 1.59 0.72 ...
#  $ calculated_host_listings_count: int  1 33 33 2 1 3 3 29 29 29 ...
#  $ availability_365              : int  339 61 133 338 80 204 198 334 325 338 ...

# %%
head(data)
# Out:
#   id    name                                            host_id
# 1 11368 CENTER. Nice attic with big TERRACE              42188
# 2 18666 Flat with Sunny Terrace                          71615
# 3 18674 Huge flat for 8 people close to Sagrada Familia  71615
# 4 21605 Nice and sunny duble room                        82522
# 5 25786 NICE ROOM AVAILABLE IN THE HEART OF GRACIA      108310
# 6 31377 Room for 2,  Sagrada Famili                     134698
#   host_name        neighbourhood_group neighbourhood
# 1 Paola            Ciutat Vella        Sant Pere, Santa Caterina i la Ribera
# 2 Mireia And Maria Sant Martí          el Camp de l'Arpa del Clot
# 3 Mireia And Maria Eixample            la Sagrada Família
# 4 Meritxell        Sant Martí          el Poblenou
# 5 Pedro            Gràcia              la Vila de Gràcia
# 6 Svetlana         Horta-Guinardó      el Baix Guinardó
#   latitude longitude room_type       price minimum_nights number_of_reviews
# 1 41.38751 2.178608  Entire home/apt 100   3               41
# 2 41.40889 2.185545  Entire home/apt 130   3                1
# 3 41.40420 2.173058  Entire home/apt  95   1                5
# 4 41.40560 2.198205  Private room     33   2               90
# 5 41.40145 2.156447  Private room     42   1              204
# 6 41.41097 2.170701  Private room     42   3                4
#   last_review reviews_per_month calculated_host_listings_count availability_365
# 1 2018-08-18  0.45               1                             339
# 2 2015-10-10  0.03              33                              61
# 3 2018-06-18  0.08              33                             133
# 4 2018-08-20  3.15               2                             338
# 5 2018-09-05  2.07               1                              80
# 6 2018-03-12  0.10               3                             204

# %%
class(data)
# Out:
# [1] "tbl_df"     "tbl"        "data.frame"

# %% [markdown]
# Next, you can see some example of how to select data from a `data.frame`

# %%
data[1, ] # first row
# Out:
#   id    name                                host_id host_name
# 1 11368 CENTER. Nice attic with big TERRACE 42188   Paola
#   neighbourhood_group neighbourhood                         latitude longitude
# 1 Ciutat Vella        Sant Pere, Santa Caterina i la Ribera 41.38751 2.178608
#   room_type       price minimum_nights number_of_reviews last_review
# 1 Entire home/apt 100   3              41                2018-08-18
#   reviews_per_month calculated_host_listings_count availability_365
# 1 0.45              1                              339

# %%
data[1:3, ] # first three rows
# Out:
#   id    name                                            host_id
# 1 11368 CENTER. Nice attic with big TERRACE             42188
# 2 18666 Flat with Sunny Terrace                         71615
# 3 18674 Huge flat for 8 people close to Sagrada Familia 71615
#   host_name        neighbourhood_group neighbourhood
# 1 Paola            Ciutat Vella        Sant Pere, Santa Caterina i la Ribera
# 2 Mireia And Maria Sant Martí          el Camp de l'Arpa del Clot
# 3 Mireia And Maria Eixample            la Sagrada Família
#   latitude longitude room_type       price minimum_nights number_of_reviews
# 1 41.38751 2.178608  Entire home/apt 100   3              41
# 2 41.40889 2.185545  Entire home/apt 130   3               1
# 3 41.40420 2.173058  Entire home/apt  95   1               5
#   last_review reviews_per_month calculated_host_listings_count availability_365
# 1 2018-08-18  0.45               1                             339
# 2 2015-10-10  0.03              33                              61
# 3 2018-06-18  0.08              33                             133

# %%
data[, 1] # first column
# Out:
#   id
# 1 11368
# 2 18666
# 3 18674
# 4 21605
# 5 25786
# 6 31377

# %%
data[, 2:5] # from column 2 to 5

# %%
data[, "id"] # select column by name

# %%
data$id # select column by name (another way)

# %%
head(data, 6)
# Out:
#   id    name                                            host_id
# 1 11368 CENTER. Nice attic with big TERRACE              42188
# 2 18666 Flat with Sunny Terrace                          71615
# 3 18674 Huge flat for 8 people close to Sagrada Familia  71615
# 4 21605 Nice and sunny duble room                        82522
# 5 25786 NICE ROOM AVAILABLE IN THE HEART OF GRACIA      108310
# 6 31377 Room for 2,  Sagrada Famili                     134698
#   host_name        neighbourhood_group neighbourhood
# 1 Paola            Ciutat Vella        Sant Pere, Santa Caterina i la Ribera
# 2 Mireia And Maria Sant Martí          el Camp de l'Arpa del Clot
# 3 Mireia And Maria Eixample            la Sagrada Família
# 4 Meritxell        Sant Martí          el Poblenou
# 5 Pedro            Gràcia              la Vila de Gràcia
# 6 Svetlana         Horta-Guinardó      el Baix Guinardó
#   latitude longitude room_type       price minimum_nights number_of_reviews
# 1 41.38751 2.178608  Entire home/apt 100   3               41
# 2 41.40889 2.185545  Entire home/apt 130   3                1
# 3 41.40420 2.173058  Entire home/apt  95   1                5
# 4 41.40560 2.198205  Private room     33   2               90
# 5 41.40145 2.156447  Private room     42   1              204
# 6 41.41097 2.170701  Private room     42   3                4
#   last_review reviews_per_month calculated_host_listings_count availability_365
# 1 2018-08-18  0.45               1                             339
# 2 2015-10-10  0.03              33                              61
# 3 2018-06-18  0.08              33                             133
# 4 2018-08-20  3.15               2                             338
# 5 2018-09-05  2.07               1                              80
# 6 2018-03-12  0.10               3                             204

# %%
tail(data, 2)
# Out:
#   id       name                                               host_id
# 1 28437424 Comfy double room in BCN center                    51807276
# 2 28439051 Un apartamento tranquilo en la ciudad de Barcelona  1035045
#   host_name  neighbourhood_group neighbourhood latitude longitude
# 1 Murrey     Eixample            Sant Antoni   41.38015 2.158336
# 2 Montserrat Sant Andreu         Sant Andreu   41.44145 2.187336
#   room_type       price minimum_nights number_of_reviews last_review
# 1 Private room    30      2            0
# 2 Entire home/apt 60    180            0
#   reviews_per_month calculated_host_listings_count availability_365
# 1 NA                2                               57
# 2 NA                8                              365

# %%
first(data$host_name) #  first position of a vector
# Out:
# [1] Paola
# 4178 Levels:  * Noemi 08028 Apartments 88delaRambla =Cris Y Saly= A ... 顺

# %%
last(data$host_name) # last position of a vector
# Out:
# [1] Montserrat
# 4178 Levels:  * Noemi 08028 Apartments 88delaRambla =Cris Y Saly= A ... 顺

# %% [markdown]
# # 2. Exploratory Data Analysis
#
#
# The goal during Exploratory Data Analysis (EDA) is to develop an understanding of your data. The easiest way to do this is to use questions as tools to guide your investigation. When you ask a question, the question focuses your attention on a specific part of your dataset and helps you decide which graphs, models, or transformations to make.
#
# There is no rule about which questions you should ask to guide your research. However, two types of questions will always be useful for making discoveries within your data. You can loosely word these questions as:
#
# * What type of variation occurs within my variables?
#
# * What type of covariation occurs between my variables?
#
#
#
#
#
#
# **Some remarks**:
# * A *variable* is a quantity, quality, or property that you can measure.
#
# * A *value* is the state of a variable when you measure it. The value of a variable may change from measurement to measurement.
#
# * An *observation* is a set of measurements made under similar conditions (you usually make all of the measurements in an observation at the same time and on the same object). An observation will contain several values, each associated with a different variable. I’ll sometimes refer to an observation as a data point.
#
#
#
# Often you’ll need to create some new variables or summaries, or maybe you just want to rename the variables or reorder the observations in order to make the data a little easier to work with.  You can see here some examples:

# %% [markdown]
# ### Dealing with missing values
#
# But before starting, a common task in data analysis is dealing with missing values. In R, missing values are often represented by `NA` or some other value that represents missing values (i.e. `99`).
#
# The first step is to identify this values. To this end, you can use `is.na()` which returns a logical vector with `TRUE` in the element locations that contain missing values represented by `NA`. `is.na()` will work on vectors, lists, matrices, and data frames.

# %%
data %>% 
  is.na() %>% 
  colSums()

# colSums(is.na(data))
# Out:
#                             id                           name
#                              0                              0
#                        host_id                      host_name
#                              0                              0
#            neighbourhood_group                  neighbourhood
#                              0                              0
#                       latitude                      longitude
#                              0                              0
#                      room_type                          price
#                              0                              0
#                 minimum_nights              number_of_reviews
#                              0                              0
#                    last_review              reviews_per_month
#                              0                           3865
# calculated_host_listings_count               availability_365
#                              0                              0

# %%
#load(file(source_data("http://dl.dropboxusercontent.com/u/25710348/Blogposts/data/IL2010.Rda")))

# %% [markdown]
# Another option to see the number of NA's is applying the `summary` function. This function produces numerical summaries for each of the variables of the variables included in the data frame.

# %%
summary(data)
# Out:
#        id                                  name          host_id
#  Min.   :   11368                            :   20   Min.   :     3073
#  1st Qu.: 8324914   Apartamento En Barcelona :   14   1st Qu.:  6767012
#  Median :18340036   Sagrada Familia Apartment:   13   Median : 34573708
#  Mean   :16238951   Habitación doble         :   12   Mean   : 65667989
#  3rd Qu.:23920552   Double room              :   11   3rd Qu.:127853658
#  Max.   :28439051   Habitación individual    :   10   Max.   :214608675
#                     (Other)                  :19120
#        host_name              neighbourhood_group
#  Eva&Jacques:  193   Eixample           :6531
#  Maria      :  190   Ciutat Vella       :4250
#  Jordi      :  185   Sants-Montjuïc     :2242
#  Claudia    :  144   Sant Martí         :2187
#  Andrea     :  135   Gràcia             :1702
#  David      :  133   Sarrià-Sant Gervasi: 682
#  (Other)    :18220   (Other)            :1606
#                                neighbourhood      latitude       longitude
#  la Dreta de l'Eixample               : 1984   Min.   :41.35   Min.   :2.088
#  el Raval                             : 1484   1st Qu.:41.38   1st Qu.:2.157
#  el Barri Gòtic                       : 1288   Median :41.39   Median :2.168
#  la Sagrada Família                   : 1076   Mean   :41.39   Mean   :2.168
#  el Poble Sec                         : 1074   3rd Qu.:41.40   3rd Qu.:2.178
#  Sant Pere, Santa Caterina i la Ribera: 1067   Max.   :41.47   Max.   :2.227
#  (Other)                              :11227
#            room_type         price        minimum_nights     number_of_reviews
#  Entire home/apt: 8594   Min.   :   1.0   Min.   :   1.000   Min.   :  0.00
#  Private room   :10438   1st Qu.:  35.0   1st Qu.:   1.000   1st Qu.:  1.00
#  Shared room    :  168   Median :  58.0   Median :   2.000   Median :  8.00
#                          Mean   : 103.8   Mean   :   7.286   Mean   : 29.78
#                          3rd Qu.: 100.0   3rd Qu.:   3.000   3rd Qu.: 35.00
#                          Max.   :9120.0   Max.   :1100.000   Max.   :557.00
#
#      last_review    reviews_per_month calculated_host_listings_count
#            : 3865   Min.   : 0.010    Min.   :  1.00
#  2018-08-26:  553   1st Qu.: 0.470    1st Qu.:  1.00
#  2018-08-27:  484   Median : 1.220    Median :  2.00
#  2018-08-25:  396   Mean   : 1.736    Mean   : 12.42
#  2018-08-19:  365   3rd Qu.: 2.610    3rd Qu.:  8.00
#  2018-09-02:  352   Max.   :12.310    Max.   :192.00
#  (Other)   :13185   NA's   :3865
#  availability_365
#  Min.   :  0.0
#  1st Qu.: 57.0
#  Median :180.0
#  Mean   :186.1
#  3rd Qu.:322.0
#  Max.   :365.0

# %% [markdown]
# Now, we can delete these observations or we can recode them.
#
# In order to recode missing values or recode specific indicators that represent missing values, we can use normal subsetting and assignment operations. For example, we can recode missing values in vector `x` with the mean values in `x` by first subsetting the vector to identify `NA's` and then assign these elements a value.

# %%
(x <- c(1:4, NA, 6:7, NA))
# Out:
# [1]  1  2  3  4 NA  6  7 NA

# %%
x[is.na(x)] <- mean(x, na.rm = TRUE)

# %%
round(x, 2)
# Out:
# [1] 1.00 2.00 3.00 4.00 3.83 6.00 7.00 3.83

# %% [markdown]
# In our analysis, we are going to exclude these cases directly. To this end, we could use de `na.omit` function.

# %%
# data <- data[complete.cases(data), ] # another option
data <- na.omit(data)

# %% [markdown]
# ### Exploring the variation of my variables
#
# At this stage, we'll see some example to analyze one variable paying attention of their type (continuous or categorical). In the case of a continuous variable, it is commmon to use the summary function and in the case of a catgorical variable we can obtain frequencies for each of the levels of the variable.

# %%
summary(data$price) # continuous
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    8.00   35.00   56.00   90.67  100.00 9120.00

# %%
summary(data$room_type) # categorical
# Out:
# Entire home/apt    Private room     Shared room
#            6719            8500             116

# %%
table(data$room_type) # absolutes frequencies
# Out:
# Entire home/apt    Private room     Shared room
#            6719            8500             116

# %%
prop.table(table(data$room_type)) # relative frequencies
# Out:
# Entire home/apt    Private room     Shared room
#     0.438148027     0.554287577     0.007564395

# %% [markdown]
# ### Exploring the covariation between my variables
#
# Now, we'll try to understand which is the relation between some varibles and obtain results for the combination of them. We'll use some very useful fucntions from the `dplyr` packages. The first one is `filter()` that allows you to subset observations based on their values.
#
# Note: `dplyr` executes the filtering operation and returns a new data frame. `dplyr` functions never modify their inputs, so if you want to save the result, you’ll need to use the assignment operator, `<-`.

# %%
data %>%
  filter(neighbourhood_group == "Ciutat Vella",
         room_type == "Private room")

# ciutat_vella_priv_room <- data %>%
#  filter(neighbourhood_group == "Ciutat Vella",
#         room_type == "Private room")
# Out:
#      id       name                                               host_id
# 1     36763   In front of the beach                               158596
# 2     68547   two beds with private shower 30% off                340570
# 3     70099   Room with a View, Bcn City Center                   353987
# 4     74562   Cute Suite near the MACBA                           382031
# 5     95719   Lovely room to rent in El Gotico                    509260
# 6    119546   BCN HUGEROOM DTOWN PRIVATE BATHROOM.                603336
# 2085 Sebastian  Ciutat Vella        el Barri Gòtic
# 2086 Nina       Ciutat Vella        Sant Pere, Santa Caterina i la Ribera
# 2087 Neus       Ciutat Vella        Sant Pere, Santa Caterina i la Ribera
# 2088 Emma       Ciutat Vella        Sant Pere, Santa Caterina i la Ribera
# 2089 Diego      Ciutat Vella        el Raval
# 2090 Marco      Ciutat Vella        el Barri Gòtic
# 2091 Nasira     Ciutat Vella        el Raval
# 2092 Marco      Ciutat Vella        el Barri Gòtic
# 2093 Andres     Ciutat Vella        el Barri Gòtic
#      latitude longitude room_type    price minimum_nights number_of_reviews
# 1    41.37906 2.191414  Private room  38    2              48
# 2    41.38072 2.178109  Private room  47    2              58
# 3    41.37828 2.170805  Private room  44    1             267
# 4    41.38255 2.168365  Private room  65    3             162
# 5    41.38390 2.180115  Private room  53    2             176
# 6    41.37969 2.165318  Private room  69    3             253
# 7    41.38297 2.170672  Private room  28    2              83
# 8    41.37799 2.172807  Private room  50    3             236
# 9    41.38341 2.172568  Private room  60   12              88
# 10   41.38430 2.167994  Private room  23   32              18
# 11   41.38059 2.168827  Private room  55    3             118
# 12   41.38281 2.181483  Private room  70    1              60
# 13   41.38180 2.165272  Private room  47    2             307
# 14   41.38472 2.181491  Private room  85    1              59
# 15   41.38477 2.183576  Private room  35   25               4
# 16   41.37886 2.168839  Private room  49    1             272
# 17   41.38771 2.176303  Private room  40    2             248
# 18   41.38818 2.175710  Private room  40    2             198
# 19   41.38484 2.177958  Private room  42    4             278
# 20   41.38047 2.167980  Private room  35    3              36
# 21   41.38493 2.172454  Private room  50    4              35
# 22   41.37654 2.173845  Private room  35    3             203
# 23   41.38065 2.176289  Private room  50    2             116
# 24   41.38406 2.179257  Private room  40    3              77
# 25   41.38217 2.163745  Private room  40    2              62
# 26   41.38618 2.172052  Private room 114    4              95
# 27   41.37707 2.187873  Private room  80    3             136
# 28   41.38466 2.180002  Private room  48    1             368
# 29   41.38210 2.164001  Private room  32    2              90
# 30   41.38587 2.164845  Private room  88    3              41
# ⋮    ⋮        ⋮         ⋮            ⋮     ⋮              ⋮
# 2064 41.37767 2.177467  Private room  35   2              2
# 2065 41.37846 2.175977  Private room  90   2              2
# 2066 41.38554 2.193998  Private room  55   3              1
# 2067 41.38028 2.178583  Private room  53   1              3
# 2068 41.38089 2.177967  Private room  56   1              2
# 2069 41.37925 2.178398  Private room  51   1              2
# 2070 41.37945 2.177686  Private room  48   3              2
# 2071 41.37921 2.187551  Private room  80   1              2
# 2072 41.37931 2.191413  Private room  50   1              1
# 2073 41.37809 2.165876  Private room  70   1              2
# 2074 41.37778 2.166366  Private room  45   1              3
# 2075 41.38541 2.179601  Private room  68   1              1
# 2076 41.38546 2.180834  Private room  50   1              2
# 2077 41.38675 2.180846  Private room  50   1              1
# 2078 41.37889 2.172339  Private room  80   1              3
# 2079 41.37800 2.168334  Private room  35   1              2
# 2080 41.38056 2.175368  Private room 160   2              1
# 2081 41.38232 2.177256  Private room 120   2              1
# 2082 41.38310 2.173222  Private room  35   3              1
# 2083 41.37860 2.166598  Private room  36   1              1
# 2069 100
# 2070  96
# 2071  13
# 2072  13
# 2073 341
# 2074 346
# 2075 348
# 2076  57
# 2077  59
# 2078 155
# 2079 353
# 2080 348
# 2081 332
# 2082   6
# 2083  13
# 2084  57
# 2085 161
# 2086 279
# 2087  50
# 2088   5
# 2089 159
# 2090  88
# 2091  15
# 2092  56
# 2093   3

# %%
# data %>%
#  filter(neighbourhood_group == "Ciutat Vella"| neighbourhood_group == "Gràcia" ) # logic operators

# data %>%
#  filter(neighbourhood_group %in% c("Ciutat Vella","Gràcia" )) # logic operators

# %% [markdown]
# The function `arrange()` works similarly to `filter()` except that instead of selecting rows, it changes their order. It takes a data frame and a set of column names to order by. If you provide more than one column name, each additional column will be used to break ties in the values of preceding columns:

# %%
data %>% 
  arrange(price, desc(number_of_reviews))
# Out:
#       id       name                                               host_id
# 1     13978164 HABITACIÓN DOBLE TIPO LOFT                          15920367
# 2     20965155 2 sleeper placea for 2 persons in shared room!      73976926
# 3     20964827 1 sleeper place in shared room!                     73976926
# 4     20965167 2 sleeper placea for 2 persons in shared room!      73976926
# 5     20950570 1 sleeper place in shared room!                     73976926
# 6     20964442 1 sleeper place in shared room!                     73976926
# 7     20964105 1 sleeper place in shared room!                     73976926
# 8     20965152 2 sleeper placea for 2 persons in shared room!      73976926
# 9     20964444 1 sleeper place in shared room!                     73976926
# 10    20965154 2 sleeper placea for 2 persons in shared room!      73976926
# 11    20964826 1 sleeper place in shared room!                     73976926
# 12    20964440 1 sleeper place in shared room!                     73976926
# 13    24319577 Habitacion doble MUY CENTRICA 5min rambla exterior  19568982
# 14    20950596 1 sleeper place in shared room!                     73976926
# 15     3390888 Comfy,Nice&Afordable Room 1820 renovated building   17107294
# 16    19599788 Nice, comfy and quiet room in the center.          137797890
# 17    20879601 Central room-Walk everywhere and sleep like a baby  17107294
# 18    11825402 Habitación individual en el centro!                 62984598
# 19     3724013 Nice room for 4 persons                              9547606
# 20    21555225 Central 5beds w/ Private Bathroom + Breakfast (B1) 156735550
# 21    21555512 Super Central 2 Beds Room & Free Breakfast (B2)    156735550
# 22     8529563 Nice room №6 for 3 persons                           9547606
# 23    23049688 Central Redroom with Breakfast                      54082387
# 24    11677514 Clean, sunny and cozy room 5  Camp Nou               9547606
# 25    23014330 Listing cancelled                                  148379379
# 26    22110818 Private Bathroom & Free Breakfast (2)               54082387
# 27    23034004 GIGANTIC SUNNY ROOM in city CENTRE up to 5 ppl      19568982
# 28     8990923 Comfortable Cama                                    46963628
# 29    13873341 Central, clean & good room                          53444312
# 30    22218299 Habitacion individual exterior en Sants            162349823
# ⋮     ⋮        ⋮                                                  ⋮
# 15306 22741274 Central, 2 bedrooms, shared terrace, stylish, AC   163429849
# 15307 10133050 Central luxury apartment with chillout terrace B10  10380563
# 15308 22367519 1 bedroom, shared terrace, central, stylish, AC    163429849
# 15309  8414793 Lugaris Beach Quadruple Apartment                     375625
# 15310 22741727 1 bedroom, shared terrace, central, stylish,  AC   163429849
# 15311 24196303 Bright, elegant, 2 bedrooms, Sagrada Familia, AC     5878688
# 15320 la Vila de Gràcia                            41.39662 2.158804
# 15321 la Dreta de l'Eixample                       41.39229 2.165006
# 15322 la Vila de Gràcia                            41.39800 2.159430
# 15323 Diagonal Mar i el Front Marítim del Poblenou 41.40867 2.215185
# 15324 el Raval                                     41.38104 2.169862
# 15325 la Vila de Gràcia                            41.39669 2.157106
# 15326 la Vila de Gràcia                            41.39810 2.158447
# 15327 la Font d'en Fargues                         41.42705 2.164543
# 15328 Sant Andreu                                  41.43720 2.191239
# 15329 Sant Antoni                                  41.37729 2.154437
# 15330 l'Antiga Esquerra de l'Eixample              41.38644 2.163833
# 15331 la Maternitat i Sant Ramon                   41.37793 2.116669
# 15332 la Maternitat i Sant Ramon                   41.37832 2.117387
# 15333 la Vila Olímpica del Poblenou                41.39096 2.199587
# 15334 el Camp d'en Grassot i Gràcia Nova           41.40360 2.168802
# 15335 el Poble Sec                                 41.37265 2.169186
#       room_type       price minimum_nights number_of_reviews last_review
# 1     Private room    8      2              71               2018-08-30
# 2     Shared room     8      1              31               2018-08-19
# 3     Shared room     8      1              27               2018-08-31
# 4     Shared room     8      1              25               2018-09-06
# 5     Shared room     8      1              17               2018-09-09
# 6     Shared room     8      1              16               2018-07-21
# 7     Shared room     8      1              14               2018-09-01
# 8     Shared room     8      1              13               2018-08-31
# 9     Shared room     8      1              11               2018-09-06
# 10    Shared room     8      1              10               2018-04-01
# 11    Shared room     8      1               9               2018-09-07
# 12    Shared room     8      1               7               2018-07-21
# 13    Private room    8      1               4               2018-09-05
# 14    Shared room     8      1               3               2018-01-19
# 15    Private room    9      1             386               2018-09-07
# 16    Private room    9      1              83               2018-09-08
# 17    Private room    9      1              82               2018-09-09
# 18    Private room    9      2              71               2018-09-02
# 19    Shared room     9      2              66               2018-08-19
# 20    Private room    9      1              28               2018-09-03
# 21    Private room    9      1              27               2018-08-20
# 22    Private room    9      2              26               2018-07-24
# 23    Private room    9      1              16               2018-08-24
# 24    Private room    9      2              15               2018-08-04
# 25    Private room    9     32              15               2018-07-22
# 26    Private room    9      1               8               2018-05-23
# 27    Private room    9      1               8               2018-08-15
# 28    Private room    9      1               1               2015-10-22
# 29    Private room    9      1               1               2016-08-16
# 30    Private room    9      1               1               2018-01-13
# ⋮     ⋮               ⋮     ⋮              ⋮                 ⋮
# 15306 Entire home/apt 1000    2             17               2018-08-10
# 15307 Entire home/apt 1000    3             15               2018-08-10
# 15308 Entire home/apt 1000    2             14               2018-08-29
# 15309 Entire home/apt 1000    3             13               2018-09-03
# 15310 Entire home/apt 1000    2             13               2018-08-29
# 15311 Entire home/apt 1000    2             13               2018-09-04
# 15312 Entire home/apt 1000    3             12               2018-08-24
# 15313 Entire home/apt 1000    2             12               2018-08-12
# 15314 Entire home/apt 1000    2             10               2018-06-17
# 15315 Entire home/apt 1000    2             10               2018-09-05
# 15316 Entire home/apt 1000    3              9               2017-08-17
# 15317 Entire home/apt 1000    2              8               2018-08-17
# 15318 Entire home/apt 1000    2              8               2018-08-29
# 15319 Entire home/apt 1000    2              7               2018-05-26
# 15320 Entire home/apt 1000    2              7               2018-08-28
# 15321 Entire home/apt 1000    3              5               2018-07-12
# 15322 Shared room     1000    2              4               2018-06-08
# 15323 Entire home/apt 1000    4              3               2018-07-20
# 15324 Private room    1000    1              3               2018-07-23
# 15325 Entire home/apt 1000    2              1               2018-05-14
# 15326 Entire home/apt 1000    2              1               2018-02-25
# 15327 Entire home/apt 1136    3              8               2018-06-18
# 15328 Entire home/apt 1200    1              6               2018-08-25
# 15329 Entire home/apt 1500  100             67               2017-03-13
# 15330 Private room    2500    1              6               2016-09-26
# 15331 Entire home/apt 3000    2            108               2018-08-25
# 15332 Entire home/apt 3000    2             89               2018-08-27
# 15333 Entire home/apt 3000    3             51               2016-11-02
# 15334 Private room    5000    1              1               2016-05-30
# 15335 Private room    9120    2              7               2016-07-04
#       reviews_per_month calculated_host_listings_count availability_365
# 1     2.79               5                               7
# 2     3.38              12                             362
# 3     3.31              12                             364
# 4     2.79              12                             358
# 5     1.49              12                             362
# 6     1.43              12                             362
# 7     1.30              12                             362
# 8     1.40              12                             361
# 9     0.98              12                             364
# 10    0.92              12                             362
# 11    0.81              12                             362
# 12    0.66              12                             364
# 13    0.84               8                              44
# 14    0.26              12                             364
# 15    7.53               2                              77
# 16    5.76               2                              45
# 17    6.83               2                              18
# 18    2.37               2                             172
# 19    1.34               7                             347
# 20    2.71              19                              81
# 21    2.60              19                              89
# 22    0.75               7                             334
# 23    2.35              11                              23
# 24    0.53               7                             340
# 25    2.49               1                               0
# 26    0.93              11                              23
# 27    1.46               8                              56
# 28    0.03               1                               0
# 29    0.04               1                               0
# 30    0.12               1                               0
# ⋮     ⋮                 ⋮                              ⋮
# 15306 2.54              15                             327
# 15307 0.87              41                             320
# 15308 2.13              15                             238
# 15309 0.39               5                             355
# 15310 2.09              15                             327
# 15311 3.68              60                             294
# 15312 0.40              41                             306
# 15313 2.02              15                             305
# 15314 0.46               6                             361
# 15315 1.52              15                             333
# 15316 0.51               4                              12
# 15317 1.22              15                             321
# 15318 1.24              15                             323
# 15319 1.06              15                             337
# 15320 1.10              15                             342
# 15321 0.35              41                             317
# 15322 0.62              15                             250
# 15323 0.07               5                             364
# 15324 0.22               2                              30
# 15325 0.25              15                             342
# 15326 0.15              15                             342
# 15327 0.18               6                             301
# 15328 0.41               1                             358
# 15329 1.10               2                             352
# 15330 0.24               1                             279
# 15331 5.30               2                             144
# 15332 4.47               2                             142
# 15333 0.76               1                             222
# 15334 0.04               1                             365
# 15335 0.25               1                               0

# %% [markdown]
# Besides selecting sets of existing columns, sometimes it's very useful to add new columns that are obtained from existing columns. That’s the job of `mutate()`.

# %%
data <- data %>% 
  mutate(ri_price = price > quantile(price, probs = 0.25) &
           price < quantile(price, probs = 0.75))

# %%
head(data)
# Out:
#   id    name                                            host_id
# 1 11368 CENTER. Nice attic with big TERRACE              42188
# 2 18666 Flat with Sunny Terrace                          71615
# 3 18674 Huge flat for 8 people close to Sagrada Familia  71615
# 4 21605 Nice and sunny duble room                        82522
# 5 25786 NICE ROOM AVAILABLE IN THE HEART OF GRACIA      108310
# 6 31377 Room for 2,  Sagrada Famili                     134698
#   host_name        neighbourhood_group neighbourhood
# 1 Paola            Ciutat Vella        Sant Pere, Santa Caterina i la Ribera
# 2 Mireia And Maria Sant Martí          el Camp de l'Arpa del Clot
# 3 Mireia And Maria Eixample            la Sagrada Família
# 4 Meritxell        Sant Martí          el Poblenou
# 5 Pedro            Gràcia              la Vila de Gràcia
# 6 Svetlana         Horta-Guinardó      el Baix Guinardó
#   latitude longitude room_type       price minimum_nights number_of_reviews
# 1 41.38751 2.178608  Entire home/apt 100   3               41
# 2 41.40889 2.185545  Entire home/apt 130   3                1
# 3 41.40420 2.173058  Entire home/apt  95   1                5
# 4 41.40560 2.198205  Private room     33   2               90
# 5 41.40145 2.156447  Private room     42   1              204
# 6 41.41097 2.170701  Private room     42   3                4
#   last_review reviews_per_month calculated_host_listings_count availability_365
# 1 2018-08-18  0.45               1                             339
# 2 2015-10-10  0.03              33                              61
# 3 2018-06-18  0.08              33                             133
# 4 2018-08-20  3.15               2                             338
# 5 2018-09-05  2.07               1                              80
# 6 2018-03-12  0.10               3                             204
#   ri_price
# 1 FALSE
# 2 FALSE
# 3  TRUE
# 4 FALSE
# 5  TRUE
# 6  TRUE

# %% [markdown]
# `select()` allows you to rapidly zoom in on a useful subset using operations based on the names of the variables.

# %%
data %>% 
    select(name, price)  %>% 
    head()

#data %>% select(price, ri_price)
# Out:
#   name                                            price
# 1 CENTER. Nice attic with big TERRACE             100
# 2 Flat with Sunny Terrace                         130
# 3 Huge flat for 8 people close to Sagrada Familia  95
# 4 Nice and sunny duble room                        33
# 5 NICE ROOM AVAILABLE IN THE HEART OF GRACIA       42
# 6 Room for 2,  Sagrada Famili                      42

# %% [markdown]
# In order to answer some questions, you'll need to use more than one function at once. For example, how many distinct `neighbourhood` are there in `Ciutat Vella`?

# %%
data %>%
    filter(neighbourhood_group == "Ciutat Vella") %>% 
    select(neighbourhood) %>% 
    unique()
# Out:
#   neighbourhood
# 1 Sant Pere, Santa Caterina i la Ribera
# 2 el Barri Gòtic
# 3 la Barceloneta
# 4 el Raval

# %%
# pay attention!
 data %>%
#    filter(neighbourhood_group == "Ciutat Vella") %>% 
    select(neighbourhood) %>% 
    unique()
# Out:
#    neighbourhood
# 1  Sant Pere, Santa Caterina i la Ribera
# 2  el Camp de l'Arpa del Clot
# 3  la Sagrada Família
# 4  el Poblenou
# 5  la Vila de Gràcia
# 6  el Baix Guinardó
# 7  l'Antiga Esquerra de l'Eixample
# 8  el Camp d'en Grassot i Gràcia Nova
# 9  la Dreta de l'Eixample
# 10 el Barri Gòtic
# 11 la Barceloneta
# 12 el Poble Sec
# 13 el Fort Pienc
# 14 el Raval
# 15 Vallcarca i els Penitents
# 16 Hostafrancs
# 17 el Clot
# 18 Sant Antoni
# 19 Vallvidrera, el Tibidabo i les Planes
# 20 la Sagrera
# 21 Sants
# 22 Diagonal Mar i el Front Marítim del Poblenou
# 23 Pedralbes
# 24 el Guinardó
# 25 les Corts
# 26 Sant Andreu
# 27 Provençals del Poblenou
# 28 Horta
# 29 el Besòs i el Maresme
# 30 la Salut
# ⋮  ⋮
# 43 el Congrés i els Indians
# 44 Navas
# 45 Vilapicina i la Torre Llobeta
# 46 la Verneda i la Pau
# 47 Torre Baró
# 48 les Tres Torres
# 49 el Turó de la Peira
# 50 Sant Genís dels Agudells
# 51 la Font d'en Fargues
# 52 la Maternitat i Sant Ramon
# 53 el Carmel
# 54 Canyelles
# 55 la Teixonera
# 56 Sant Gervasi - la Bonanova
# 57 Can Baró
# 58 la Marina del Prat Vermell
# 59 el Bon Pastor
# 60 Porta
# 61 la Guineueta
# 62 la Vall d'Hebron
# 63 Montbau
# 64 la Prosperitat
# 65 Ciutat Meridiana
# 66 Verdun
# 67 les Roquetes
# 68 la Trinitat Nova
# 69 Vallbona
# 70 la Trinitat Vella
# 71 Baró de Viver
# 72 Can Peguera

# %% [markdown]
# Finally,  together `group_by()` and `summarise()` provide one of the tools that you’ll use most commonly when working with `dplyr`: **grouped summaries**.

# %%
data %>% 
  group_by(neighbourhood_group) %>% 
  summarise(mean = mean(price))
# Out:
#    neighbourhood_group mean
# 1  Ciutat Vella         72.79563
# 2  Eixample            114.05469
# 3  Gràcia               91.75055
# 4  Horta-Guinardó       68.25400
# 5  Les Corts            83.39252
# 6  Nou Barris           34.37566
# 7  Sant Andreu          48.22835
# 8  Sant Martí           82.72783
# 9  Sants-Montjuïc       77.69387
# 10 Sarrià-Sant Gervasi 104.94057

# %%
# adding the number of listenings, min and max
data %>% 
  group_by(room_type) %>% 
  summarise(n = n(), mean = mean(price), 
            min = min(price), max = max(price))
# Out:
#   room_type       n    mean      min max
# 1 Entire home/apt 6719 147.52731 10  3000
# 2 Private room    8500  46.48882  8  9120
# 3 Shared room      116  35.41379  8  1000

# %%
# the same but nested grouping (by neighbourhood_group and  type of room)

data %>% 
  group_by(neighbourhood_group, room_type) %>% 
  summarise(mean = mean(price), n = n())
# Out:
#    neighbourhood_group room_type       mean      n
# 1  Ciutat Vella        Entire home/apt 108.87919 1192
# 2  Ciutat Vella        Private room     52.45246 2093
# 3  Ciutat Vella        Shared room      39.46154   13
# 4  Eixample            Entire home/apt 173.73705 2799
# 5  Eixample            Private room     46.93220 2463
# 6  Eixample            Shared room      35.50000   22
# 7  Gràcia              Entire home/apt 134.96997  666
# 8  Gràcia              Private room     50.42291  681
# 9  Gràcia              Shared room      65.08333   24
# 10 Horta-Guinardó      Entire home/apt 148.71329  143
# 11 Horta-Guinardó      Private room     36.05915  355
# 12 Horta-Guinardó      Shared room      30.00000    2
# 13 Les Corts           Entire home/apt 153.82031  128
# 14 Les Corts           Private room     36.94737  190
# 15 Les Corts           Shared room      20.00000    3
# 16 Nou Barris          Entire home/apt  81.42857   14
# 17 Nou Barris          Private room     30.31792  173
# 18 Nou Barris          Shared room      56.00000    2
# 19 Sant Andreu         Entire home/apt  93.86441   59
# 20 Sant Andreu         Private room     34.79058  191
# 21 Sant Andreu         Shared room      16.75000    4
# 22 Sant Martí          Entire home/apt 151.98707  696
# 23 Sant Martí          Private room     39.56198 1089
# 24 Sant Martí          Shared room      19.73684   19
# 25 Sants-Montjuïc      Entire home/apt 119.14605  760
# 26 Sants-Montjuïc      Private room     48.80288 1040
# 27 Sants-Montjuïc      Shared room      21.65385   26
# 28 Sarrià-Sant Gervasi Entire home/apt 157.65267  262
# 29 Sarrià-Sant Gervasi Private room     43.96000  225
# 30 Sarrià-Sant Gervasi Shared room      15.00000    1

# %%
# now we add the relative frequencies

data %>% 
  group_by(neighbourhood_group, room_type) %>% 
  summarise(mean = mean(price), n = n()) %>% 
  mutate(prop = prop.table(n))
# Out:
#    neighbourhood_group room_type       mean      n    prop
# 1  Ciutat Vella        Entire home/apt 108.87919 1192 0.361431170
# 2  Ciutat Vella        Private room     52.45246 2093 0.634627047
# 3  Ciutat Vella        Shared room      39.46154   13 0.003941783
# 4  Eixample            Entire home/apt 173.73705 2799 0.529712339
# 5  Eixample            Private room     46.93220 2463 0.466124148
# 6  Eixample            Shared room      35.50000   22 0.004163512
# 7  Gràcia              Entire home/apt 134.96997  666 0.485776805
# 8  Gràcia              Private room     50.42291  681 0.496717724
# 9  Gràcia              Shared room      65.08333   24 0.017505470
# 10 Horta-Guinardó      Entire home/apt 148.71329  143 0.286000000
# 11 Horta-Guinardó      Private room     36.05915  355 0.710000000
# 12 Horta-Guinardó      Shared room      30.00000    2 0.004000000
# 13 Les Corts           Entire home/apt 153.82031  128 0.398753894
# 14 Les Corts           Private room     36.94737  190 0.591900312
# 15 Les Corts           Shared room      20.00000    3 0.009345794
# 16 Nou Barris          Entire home/apt  81.42857   14 0.074074074
# 17 Nou Barris          Private room     30.31792  173 0.915343915
# 18 Nou Barris          Shared room      56.00000    2 0.010582011
# 19 Sant Andreu         Entire home/apt  93.86441   59 0.232283465
# 20 Sant Andreu         Private room     34.79058  191 0.751968504
# 21 Sant Andreu         Shared room      16.75000    4 0.015748031
# 22 Sant Martí          Entire home/apt 151.98707  696 0.385809313
# 23 Sant Martí          Private room     39.56198 1089 0.603658537
# 24 Sant Martí          Shared room      19.73684   19 0.010532151
# 25 Sants-Montjuïc      Entire home/apt 119.14605  760 0.416210296
# 26 Sants-Montjuïc      Private room     48.80288 1040 0.569550931
# 27 Sants-Montjuïc      Shared room      21.65385   26 0.014238773
# 28 Sarrià-Sant Gervasi Entire home/apt 157.65267  262 0.536885246
# 29 Sarrià-Sant Gervasi Private room     43.96000  225 0.461065574
# 30 Sarrià-Sant Gervasi Shared room      15.00000    1 0.002049180

# %% [markdown]
# ### Data visualization
#
# Finally we will see how to visualise your data using `ggplot2`. R has several systems for making graphs, but `ggplot2` is one of the most elegant and most versatile package.
#
#
# The way that you visualize the distribution of a variable depend on the type of variable you have: categorical or continuous.
#
#
#
# A variable is categorical if it can only take one of a small set of values. In R, categorical variables are usually saved as factors or character vectors. To examine the distribution of a categorical variable, use a bar chart:

# %%
ggplot(data = data) +
  geom_bar(aes(x = neighbourhood_group)) + ylab("hola")
# Out:
# png
#   2

# %%
?options

# %%
options(jupyter.plot_mimetypes = "image/png")

# %%
A variable is continuous if it can take any of an infinite set of ordered values. Numbers and date-times are two examples of continuous variables. To examine the distribution of a continuous variable, use a histogram:
